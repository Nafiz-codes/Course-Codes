# %%
# Given two parent chromose strings, write a function for double-point crossover
# Choose two random crossover indices
# Example:
# Parent 1: p1 = "1111111111"
# Parent 2: p2 = "0000000000"
# Crossover indices: i1 = 3, i2 = 6
# Child 1: c1 = "1111000111"
# Child 2: c2 = "0000111000"
# Output: 1111000111, 0000111000

# %%
# Note: MAKE A COPY OF THIS NOTEBOOK TO EDIT

# %%
import random

def double_point_crossover(p1, p2):

  # Check the lengths. We cannot perform crossover if lengths of parents are not equal.
  if len(p1) != len(p2):
    print(-1)
  else:
    i1 = random.randint(1,10)
    i2 = random.randint(1,10)

    if i1>=i2:
      sl1 = p1[i2:i1]
      sl2 = p2[i2:i1]

      c1 = p1[:i2] + sl2 + p1[i1:len(p1)]
      c2 = p2[:i2] + sl1 + p2[i1:len(p2)]
    else:
      sl1 = p1[i1:i2]
      sl2 = p2[i1:i2]
      c1 = p1[:i1] + sl2 + p1[i2:len(p1)]
      c2 = p2[:i1] + sl1 + p2[i2:len(p2)]

    return c1, c2



  # Choose two random crossover indices.
  # random.randint(1, 10) -> generates a random integer between 1 and 10



  # Perform double-point crossover to produce two children.
  # arr[m:n] -> extracts element from indices m to (n-1) from arr
  # arr[:n] -> extracts element from indices 0 to (n-1) from arr


  # Return the children

# %%
# tester

p1 = "1111111111"
p2 = "0000000000"

c1, c2 = double_point_crossover(p1, p2)

print(c1, c2)
# Out:
# 3 8
# 1110000011 0001111100

# %%
p1 = "123456789"
t1= p1[:3]
t2= p1[3:6]
t3= p1[6:len(p1)]
print(t1,t2,t3)
# Out:
# 123 456 789
